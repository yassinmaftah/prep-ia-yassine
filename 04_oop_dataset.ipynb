# %%
import sys
sys.path.append('..')

# %%
from src.dataset import CsvDataset

# %%
ds = CsvDataset("Promo 2026")
ds.load_from_csv("data/sample.csv")

# %%
print("Colonnes:", ds.columns)
print("the resume:", ds.summary())
# Out:
# dict_keys(['id', 'name', 'age', 'score'])
# Colonnes: ['id', 'name', 'age', 'score']
# dict_keys(['id', 'name', 'age', 'score'])
# the resume: {'name': 'Promo 2026', 'rows': 9, 'columns': ['id', 'name', 'age', 'score']}

# %%
admis = ds.filter_by_column('score', 10)
print(f"number of students are admis : {len(admis)}")
print("Liste of admis :", admis)
# Out:
# number of students are admis : 5
# Liste of admis : [{'id': '1', 'name': 'Yassine', 'age': '21', 'score': '18.5'}, {'id': '2', 'name': 'zeko', 'age': '16', 'score': '14.0'}, {'id': '5', 'name': 'bahajou', 'age': '25', 'score': '19.5'}, {'id': '9', 'name': 'ayoube', 'age': '18', 'score': '15.5'}, {'id': '10', 'name': 'mehdi', 'age': '22', 'score': '20.5'}]
