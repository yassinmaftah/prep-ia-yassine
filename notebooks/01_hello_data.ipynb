# %%
# Introduction à la Data
# Nom : Yassine
# Date : 23 Juin 2026

# %%
import sys
print("Python version:", sys.version)
print("Python path:", sys.executable)
# Out:
# Python version: 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]
# Python path: C:\Users\safiy\OneDrive\Bureau\prep-ia-yassine\.venv\Scripts\python.exe

# %%
a = 10
b = 5
total = a + b
print("Tha result of ", a, "+", b, "is", total)
# Out:
# Tha result of  10 + 5 is 15

# %%
number = [1,99,5,84,45,684,0,-996]
for n in number:
    print("the number is : ",n)
# Out:
# the number is :  1
# the number is :  99
# the number is :  5
# the number is :  84
# the number is :  45
# the number is :  684
# the number is :  0
# the number is :  -996
